# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
#Import your libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1 -  Explore the Internal Dataset
#
# In this lab, we will start off by working with the wine dataset in scikit-learn. We will select the wine dataset and use a clustering algorithm to learn more about the functionalities of this library.
#
# We start off by loading the dataset using the `load_wine` function ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_wine.html)). In the cell below, we will import the function from scikit-learn.

# %%
from sklearn.datasets import load_wine

# %% [markdown]
# In the cell below, use the `load_wine` function and assign the wine dataset to a variable called `wine`.

# %%
# use as_frame = True and use the attribute .pandas to import a pandas dataset
wine = load_wine(as_frame=True).data
wine.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %% [markdown]
# In the next step, list the keys of the variable `wine` to examine its contents. Note that the `load_wine` function does not return dataframes. It returns you a Python dictionary.

# %%
# Use .keys()
load_wine(as_frame=True).keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# Next, list the feature names. These are the different characteristics of the wine.

# %%
# Use .keys() and indicate the key feature_name
load_wine(as_frame=True)['feature_names']
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# Print the description of the dataset in the cell below using the `DESCR` attribute of the `wine` variable.
#
# *Hint: If your output is ill-formatted by displaying linebreaks as `\n`, it means you are not using the print function.*

# %%
# Print .keys() and indicate the key DESCR
print(load_wine(as_frame=True)['DESCR'])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %% [markdown]
# #### From the description, we see that all columns are numeric. We also know that there is no missing data
#
# Let's plot the alcohol content histogram. Recall that we are working with a numpy array and will need to use a matplotlib function to produce a histogram.

# %%
# Your code here:
_=plt.hist(wine['alcohol'], bins=20)

# %% [markdown]
# # Challenge 2 - Clustering the Internal Dataset
#
# In this portion of the lab, we will cluster the data to find common traits between the different wines. We will use the k-means clustering algorithm to achieve this goal.
#
# #### We start by importing k-means from scikit-learn and then proceed to create 4 clusters.

# %%
# imports
from sklearn.cluster import KMeans

# %%
# Create 4 clusters and fit data
cl = KMeans(4)
cl.fit(wine)
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# #### Print the cluster labels.

# %%
# Use .labels_ to see which cluster is each observation associated to
cl.labels_
# Out:
# array([3, 3, 1, 1, 0, 1, 1, 1, 3, 3, 1, 1, 1, 3, 1, 1, 1, 3, 1, 0, 0, 0,
#        3, 3, 0, 0, 1, 1, 3, 3, 1, 1, 3, 1, 3, 3, 3, 3, 3, 0, 0, 3, 3, 0,
#        3, 3, 3, 3, 3, 1, 3, 1, 1, 1, 3, 3, 3, 1, 1, 2, 0, 2, 0, 2, 2, 0,
#        2, 2, 0, 0, 3, 2, 2, 3, 3, 2, 2, 2, 0, 2, 2, 0, 0, 2, 2, 2, 2, 2,
#        0, 0, 2, 2, 2, 2, 2, 3, 0, 2, 0, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 0,
#        2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2,
#        2, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 2, 3, 0, 2, 0, 0, 2, 2, 2, 2, 0,
#        0, 0, 2, 3, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 0, 2, 2, 0, 0, 0, 0,
#        0, 2])

# %%
# Associate labels to each observation in the dataframe
wine['labels_k4'] = cl.predict(wine)

# %% [markdown]
# #### Compute the size of each cluster. This can be done by counting the number of occurrences of each unique label in the list above.
#
# Which is the largest cluster of the 4?

# %%
# The largest number is cluster 2
wine['labels_k4'].value_counts()
# Out:
# 2    66
# 0    56
# 3    33
# 1    23
# Name: labels_k4, dtype: int64

# %% [markdown]
# #### Inspect the shape of `wine['data']`

# %%
# Use df.shape
wine.shape
# Out:
# (178, 13)

# %% [markdown]
# #### Inspect the first 5 records in `wine['data']`

# %%
# Use .head(5)
wine.head(5)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %% [markdown]
# You now know the data object is a 2-dimensional array in which there are 178 rows and 13 columns. Each row is a data record and each column is a feature.
#
# #### What is the average ash content for each cluster?
#
# *Hints:*
#
# * *Ash* is the 3rd column.
#
# * The data object is not a Pandas dataframe so you can't apply `pandas.DataFrame.groupby`. Instead, you can use `np.average`.

# %%
# Group by labels_k4 and just obtain the mean for ash column
# Label 2, which was the most populated, has the lowest mean
wine.groupby('labels_k4')['ash'].mean()
# Out:
# labels_k4
# 0    2.406786
# 1    2.506957
# 2    2.283788
# 3    2.365758
# Name: ash, dtype: float64

# %% [markdown]
# # Challenge 3 - Load and Explore an External Dataset
#
# We will now load an external dataset using Pandas and use scikit learn to explore the data. In this portion of the lab, we will use a [patient dataset from Kaggle](https://www.kaggle.com/miles99/patient-admission-dataset-for-learning-data-mining).

# %%
patients = pd.read_csv('..\data\patient-admission-dataset-for-learning-data-mining.csv')

# %% [markdown]
# In the next cell, print the first five rows of the data using the `head()` function.

# %%
# df.head(5)
patients.head(5)
# Out:
#    id         patient_name               patient_email  doctor_phone  \
# 0   1  Celestyna Dillimore      cdillimore0@dion.ne.jp  674-914-1212
# 1   2        Meta Michieli          mmichieli1@loc.gov  172-580-3586
# 2   3        Cordie Sancto      csancto2@cafepress.com  794-222-5085
# 3   4     Josh De Ambrosis           jde3@amazon.co.jp  856-540-5195
# 4   5    Delinda Alfonsini  dalfonsini4@opensource.org  938-978-1131
#
#   patient_gender patient_dob  patient_diabetic  patient_allergic  \
# 0         Female  10/18/2018             False              True
# 1         Female    2/8/2018             False              True
# 2         Female   10/9/2018              True              True
# 3           Male   9/10/2018              True              True
# 4         Female   2/26/2018             False              True
#
#    patient_weight_kg  patient_height_sm  patient_nhs_number  \
# 0                 59                176        8.200152e+09
# ...

# %% [markdown]
# Next, print the column types and check which columns have been misclassified by pandas.

# %%
# Use df.info() to have a general overview of the columns and its types
# The ony columns missclassified are date columns
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1000 non-null   int64
#  1   patient_name          1000 non-null   object
#  2   patient_email         1000 non-null   object
#  3   doctor_phone          1000 non-null   object
#  4   patient_gender        1000 non-null   object
#  5   patient_dob           1000 non-null   datetime64[ns]
#  6   patient_diabetic      1000 non-null   bool
#  7   patient_allergic      1000 non-null   bool
#  8   patient_weight_kg     1000 non-null   int64
#  9   patient_height_sm     1000 non-null   int64
#  10  patient_nhs_number    796 non-null    float64
#  11  doctor_name           942 non-null    object
#  12  appointment_date      1000 non-null   datetime64[ns]
#  13  patient_show          1000 non-null   bool
#  14  is_regular_visit      1000 non-null   bool
# ...

# %% [markdown]
# #### We can see that none of the date columns have been correctly classified. Also, some columns contain qualitative data that can be dropped.
#
# First, transform the `patient_dob` and `appointment_date` columns to datetime using the `pd.to_datetime` function.

# %%
# Transform the two columns with pd.to_datetime
patients['patient_dob'] = pd.to_datetime(patients['patient_dob'])
patients['appointment_date'] = pd.to_datetime(patients['appointment_date'])

# %% [markdown]
# Next, drop the `id`, `patient_name`, `patient_email`, `patient_nhs_number`, and `doctor_phone` columns. These are not quantitative columns and will not contribute to our analysis.

# %%
# Use df.drop
patients.drop(columns = ['id','patient_name','patient_email','patient_nhs_number','doctor_phone'], inplace=True)

# %% [markdown]
# Now we work on the missing data. Most ML algorithms will not perform as intended if there are missing data.
#
# In the cell below, count how many rows contain missing data in each column. You should see three columns contain missing data:
#
# * `doctor_name`: 58 missing data
# * `prescribed_medicines`: 488 missing data
# * `diagnosis`: 488 missing data

# %%
# Use df.info() to have a general overview of the columns and its missing values
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 942 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patient_gender        942 non-null    object
#  1   patient_dob           942 non-null    datetime64[ns]
#  2   patient_diabetic      942 non-null    bool
#  3   patient_allergic      942 non-null    bool
#  4   patient_weight_kg     942 non-null    int64
#  5   patient_height_sm     942 non-null    int64
#  6   doctor_name           942 non-null    object
#  7   appointment_date      942 non-null    datetime64[ns]
#  8   patient_show          942 non-null    bool
#  9   is_regular_visit      942 non-null    bool
#  10  prescribed_medicines  942 non-null    object
#  11  diagnosis             942 non-null    object
# dtypes: bool(4), datetime64[ns](2), int64(2), object(4)
# memory usage: 55.2+ KB

# %% [markdown]
# The main issues are found in the `prescribed_medicines` and `diagnosis` columns. Can we simply drop these rows?
#
# The answer is not yet. Because when there are missing data in these columns, it doesn't mean the data records are broken. Instead, it means no medication was prescribed and no diagnosis was recorded. Therefore, once we fill in the missing data these columns will be fine. But we'll revisit these columns and decide whether we will eventually drop them when we look at how many unique values are there in these categorical columns.
#
# For the `prescribed_medicines` column, fill the missing values with the value `no prescription`. For the `diagnosis` column, fill the missing values with `no diagnosis`.
#
# *Hint: Use [`pandas.DataFrame.fillna`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html).*

# %%
# Use df.fillna for columns prescribed_medicines and diagnosis
patients['prescribed_medicines'].fillna('no prescription', inplace=True)
patients['diagnosis'].fillna('no diagnosis', inplace=True)

# %% [markdown]
# How about `doctor_name`? Since a doctor visit without a doctor name might not be meaningful, we will drop these rows.

# %%
# Use df.dropna. There is no need to specify the columns a sthe only misisng valeus in the whole dataframe are in column doctor_name
patients.dropna(inplace=True)

# %% [markdown]
# #### Another step in preprocessing that can be performed by scikit-learn is label encoding.
#
# We have 4 columns that are of `bool` type. We would like to convert them to an integer column containing either zero or one. We can do this using [scikit-learn's label encoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html).
#
# In the cell below, import the label encoder and encode the 4 boolean columns (*patient_diabetic*, *patient_allergic*, *patient_show*, *is_regular_visit*) with `0` and `1`.

# %%
# import
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
# Use le.fit_trandform(DataSeries) to encode the 4 columns
patients['patient_diabetic'] = le.fit_transform(patients['patient_diabetic'])
patients['patient_allergic'] = le.fit_transform(patients['patient_allergic'])
patients['patient_show'] = le.fit_transform(patients['patient_show'])
patients['is_regular_visit'] = le.fit_transform(patients['is_regular_visit'])

# %% [markdown]
# Print the data dtypes to confirm those four `bool` columns are converted to `int64`.

# %%
# Use df.info() to have a general overview of the columns and its datatypes
# Check if the columns patient_diabetic, patient_allergic, patient_show and is_regular_visit are now integrers
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 942 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patient_gender        942 non-null    object
#  1   patient_dob           942 non-null    datetime64[ns]
#  2   patient_diabetic      942 non-null    int32
#  3   patient_allergic      942 non-null    int32
#  4   patient_weight_kg     942 non-null    int64
#  5   patient_height_sm     942 non-null    int64
#  6   doctor_name           942 non-null    object
#  7   appointment_date      942 non-null    datetime64[ns]
#  8   patient_show          942 non-null    int32
#  9   is_regular_visit      942 non-null    int32
#  10  prescribed_medicines  942 non-null    object
#  11  diagnosis             942 non-null    object
# dtypes: datetime64[ns](2), int32(4), int64(2), object(4)
# memory usage: 66.2+ KB

# %% [markdown]
# #### The last step is to handle the `object` data.
#
# There are 4 `object` columns now: `patient_gender`, `doctor_name`, `prescribed_medicines`, and `diagnosis`. The gender columns
#
# In the next cell, check the unique values of each of the `object` columns using `value_counts()`.

# %%
# Your code here:
for i in patients.select_dtypes(include=object).columns:
    print(i, '\n', patients[i].value_counts(), '\n')
# Out:
# patient_gender
#  Female    476
# Male      466
# Name: patient_gender, dtype: int64
#
# doctor_name
#  Sarena Waliszek           74
# Cissy Markey              57
# Farris Robinet            55
# Flossy Canlin             55
# Glenna MacNeachtain       53
# Gabie Brafield            53
# Jilly McGrill             53
# Nerte Elmer               51
# Oralie Swaffer            49
# Kaspar Spitaro            48
# Wyn Grassett              47
# Carly SperaJillie Katt    47
# Humfried Cartmel          47
# Madelina Scurrell         46
# Rafferty Fowls            45
# Rouvin McKinstry          42
# Dulce McKerley            42
# Ryley Swallow             40
# Hermina Domeny            38
# Name: doctor_name, dtype: int64
#
# prescribed_medicines
#  no prescription                                           457
# ALCOHOL                                                     8
# Ibuprofen                                                   6
# ...

# %% [markdown]
# #### The number of unique values is large for all three columns except `patient_gender`. We will handle these columns differently.
#
# For `diagnosis`, there are too many unique values which will make ML difficult. However, we can re-encode the values to either with or without diagnosis. Remember at an earlier step we filled in the missing values of this column with *no diagnosis*? We can re-encode *no diagnosis* to `0` and all other values to `1`. In this way we can tremendously simply this column.
#
# For `prescribed_medicines`, we can drop this column because it is perfectly correlated with `diagnosis`. Whenever there is no diagnosis, there is no prescribed medicine. So we don't need to keep this duplicated data.
#
# How about `doctor_name`? There are not excessive unique values but still quite many (19). We may either drop or keep it but keeping it will make the analysis more complicated. So due to the length of this lab let's drop it.
#
# How about `gender`? This one is easy. Just like re-encoding the boolean values, we can re-encode gender to `0` and `1` because there are only 2 unique values.
#
# In the next cells, do the following:
#
# 1. Create a new column called `diagnosis_int` that has `0` and `1` based on the values in `diagnosis`.
#
# 1. Create a new column called `patient_gender_int` that has `0` and `1` based on the values in `patient_gender`.
#
# 1. Drop the following columns: `doctor_name`, `diagnosis`, `prescribed_medicines`, and `patient_gender`.

# %%
# 1 - Create new columns for diagnosis
# Use .apply and a lambda function
patients['diagnosis_int'] = patients['diagnosis'].apply(lambda x: 0 if x == 'no diagnosis' else 1)

# %%
# 2 - Create new columns for gender
# Use of LabelEncoder
patients['patient_gender_int'] = le.fit_transform(patients['patient_gender'])

# %%
# 3 - Drop the columns doctor_name, diagnosis, prescribed_medicines, and patient_gender
# Use df.drop
patients.drop(columns = ['doctor_name', 'diagnosis', 'prescribed_medicines', 'patient_gender'], inplace=True)

# %% [markdown]
# Let's look at the head again to ensure the re-encoding and dropping are successful:

# %%
# df.head()
patients.head()
# Out:
#    patient_diabetic  patient_allergic  patient_weight_kg  patient_height_sm  \
# 0                 0                 1                 59                176
# 1                 0                 1                 77                186
# 2                 1                 1                 90                177
# 3                 1                 1                 70                150
# 4                 0                 1                 82                140
#
#    patient_show  is_regular_visit  diagnosis_int  patient_gender_int  labels
# 0             1                 1              1                   0       2
# 1             1                 1              0                   0       7
# 2             0                 0              0                   0       7
# 3             0                 1              0                   1       3
# 4             0                 0              0                   0       3

# %% [markdown]
# An interesting observation is that all patients are no older than 2 years. However, their weights and heights indicate that they are adults. This cannot be true. Therefore, we can either trust the weight and height columns or the DOB column. Since there are other columns that indicate that these are adults (they have emails, some have diabetes) we will drop the `patient_dob` column. We will also drop the `appointment_date` column since it has too many unique values to transform to a dummy variable. Drop the two columns in the cell below.

# %%
# Use df.drop
patients.drop(columns = ['patient_dob', 'appointment_date'], inplace=True)

# %% [markdown]
# #### Our data is now ready for clustering. Let's use k-means again.
#
# We start by initializing and fitting a model in the cell below. Call this model patients_cluster.

# %%
# With .inertia_ we check the global distance from points to its centers, which is useful to know how many classes we need
inertias = [KMeans(k).fit(patients).inertia_ for k in range(2,10)]

# We can graphically check which would be the optimal number
plt.plot(range(2,10), inertias)

# %%
# Create clustering model and fit data
# Use 4 clusters, by having checked the elbow graph
cl = KMeans(4)
patients_cluster = cl.fit(patients)

# %% [markdown]
# Attach the labels to the dataframe. Do this by accessing the `labels_` in the `patients_cluster` model and assign them to a new column in `patients` that you will call `labels`.

# %%
# Create new columns
patients['labels'] = patients_cluster.labels_

# %% [markdown]
# Now using a `groupby`, find the mean of every variable in `patients` and group by the `labels` column. This summary will allow us to see how the patients differ between the clusters. Your output should look similar to the image below.
#
# ![groupby mean](../images/groupby-mean.png)
#
# Additionally, add a comment to describe which columns have the largest difference between clusters.

# %%
# df.groupby and mean()
patients.groupby('labels').mean()
# Out:
#         patient_diabetic  patient_allergic  patient_weight_kg  \
# labels
# 0               0.510460          0.531381          62.836820
# 1               0.504348          0.491304          65.365217
# 2               0.562500          0.526786          97.433036
# 3               0.481928          0.489960          93.987952
#
#         patient_height_sm  patient_show  is_regular_visit  diagnosis_int  \
# labels
# 0              176.924686      0.472803          0.497908       0.451883
# 1              152.304348      0.508696          0.556522       0.504348
# 2              153.593750      0.486607          0.504464       0.593750
# 3              178.911647      0.510040          0.530120       0.514056
#
#         patient_gender_int
# labels
# 0                 0.451883
# 1                 0.552174
# 2                 0.517857
# 3                 0.461847

# %% [markdown]
# # Bonus Challenge: Visualize K-Means Clusters
#
# How did k-means cluster the data? You can obtain an intuitive view with a scatter plot. Generate a 2-d cluster plot below using `matplotlib`. You need to choose 2 of the features from your cleaned and transformed dataset, and use color to represent the cluster label generated from k-means.
#
# If the scatter plot does not make any sense to you, it means the features you chose to visualize are not the right ones. You should be able to see 4 clear clusters with different colors in your visualization that suggests how k-means had clustered your data.
#
# ![Cluster Visualization](../images/clusters.png)

# %%
# First of all I will switch the type of the labels to string to better visualize the colors
patients['labels'] = patients['labels'].apply(lambda x: str(x))

# %%
# Use seaborn
sns.scatterplot(data = patients, x='patient_weight_kg', y='patient_height_sm', hue='labels')
# Out:
# <AxesSubplot:xlabel='patient_weight_kg', ylabel='patient_height_sm'>

# %% [markdown]
# Additionally, you can visualize the clusters in 3-D scatter plot. Give it a try below.

# %%
# Your code here:
